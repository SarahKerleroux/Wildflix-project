# %%
import pandas as pd

# %%
tout_df = pd.read_csv("last_df.csv")
df = pd.read_csv("df_20_000_recomandation.csv")

# %%
tout_df
# Out:
#        Unnamed: 0.1  Unnamed: 0       id  popularity original_language  \
# 0             29897           0   912649    6905.968                en
# 1             31998           1  1241982    5620.230                en
# 2             31088           2  1035048    2734.152                en
# 3             30302           3   957119    1749.575                en
# 4             30507           4   974453    1543.062                en
# ...             ...         ...      ...         ...               ...
# 32224         19785        9961   315591       0.426                fr
# 32225         17900        9962   235055       0.426                fr
# 32226         28717        9963   785341       0.425                fr
# 32227         19414        9972   296394       0.425                fr
# 32228         20315        9967   336724       0.425                fr
#
#                           title            original_title  \
# ...

# %%
tout
# Out:
# (19574, 30)

# %%
search = [el for el in tout_df['title']]

# %%
if search:
   film = df[df['title'].isin(search)]

# %%
film.shape
# Out:
# (19574, 30)
